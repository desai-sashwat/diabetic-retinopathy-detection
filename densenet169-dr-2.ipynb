ling2D
from keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.model_selection import train_test_split
import shutil
# Out:
# 2024-04-27 10:19:07.590660: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-27 10:19:07.590802: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-27 10:19:07.769455: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
from tensorflow.keras.applications.densenet import DenseNet121,DenseNet169

# %%
df = pd.read_csv(r'/kaggle/input/dr-project/id.csv')

diagnosis_dict_binary = {
    0: 'No_DR',
    1: 'DR'
}

diagnosis_dict = {
    0: 'No_DR',
    1: 'DR'
}


df['binary_type'] =  df['diagnosis'].map(diagnosis_dict_binary.get)
df['type'] = df['diagnosis'].map(diagnosis_dict.get)
df.head()
# Out:
#     id_code  diagnosis binary_type type
# 0   DR_0_61          1          DR   DR
# 1   DR_0_64          1          DR   DR
# 2   DR_0_81          1          DR   DR
# 3  DR_0_130          1          DR   DR
# 4  DR_0_137          1          DR   DR

# %%
# Split into stratified train, val, and test sets
train_intermediate, val = train_test_split(df, test_size = 0.15, stratify = df['type'])
train, test = train_test_split(train_intermediate, test_size = 0.15 / (1 - 0.15), stratify = train_intermediate['type'])

print(train['type'].value_counts(), '\n')
print(test['type'].value_counts(), '\n')
print(val['type'].value_counts(), '\n')
# Out:
# type
# No_DR    247
# DR       244
# Name: count, dtype: int64
#
# type
# DR       53
# No_DR    53
# Name: count, dtype: int64
#
# type
# DR       53
# No_DR    53
# Name: count, dtype: int64

# %%
# Create working directories for train/val/test
base_dir = ''

train_dir = os.path.join(base_dir, 'train')
val_dir = os.path.join(base_dir, 'val')
test_dir = os.path.join(base_dir, 'test')

if os.path.exists(base_dir):
    shutil.rmtree(base_dir)

if os.path.exists(train_dir):
    shutil.rmtree(train_dir)
os.makedirs(train_dir)

if os.path.exists(val_dir):
    shutil.rmtree(val_dir)
os.makedirs(val_dir)

if os.path.exists(test_dir):
    shutil.rmtree(test_dir)
os.makedirs(test_dir)

# %%
# Copy images to respective working directory
src_dir = r'/kaggle/input/dr-project/Augmented_Images'
for index, row in train.iterrows():
    diagnosis = row['type']
    binary_diagnosis = row['binary_type']
    id_code = row['id_code'] + ".jpeg"
    srcfile = os.path.join(src_dir, diagnosis, id_code)
    dstfile = os.path.join(train_dir, binary_diagnosis)
    os.makedirs(dstfile, exist_ok = True)
    shutil.copy(srcfile, dstfile)

for index, row in val.iterrows():
    diagnosis = row['type']
    binary_diagnosis = row['binary_type']
    id_code = row['id_code'] + ".jpeg"
    srcfile = os.path.join(src_dir, diagnosis, id_code)
    dstfile = os.path.join(val_dir, binary_diagnosis)
    os.makedirs(dstfile, exist_ok = True)
    shutil.copy(srcfile, dstfile)
 
for index, row in test.iterrows():
    diagnosis = row['type']
    binary_diagnosis = row['binary_type']
    id_code = row['id_code'] + ".jpeg"
    srcfile = os.path.join(src_dir, diagnosis, id_code)
    dstfile = os.path.join(test_dir, binary_diagnosis)
    os.makedirs(dstfile, exist_ok = True)
    shutil.copy(srcfile, dstfile)

# %%
# Setting up ImageDataGenerator for train/val/test 

train_path = 'train'
val_path = 'val'
test_path = 'test'

train_batches = ImageDataGenerator(rescale = 1./255).flow_from_directory(train_path, batch_size = 32, target_size=(224,224), shuffle = True)
val_batches = ImageDataGenerator(rescale = 1./255).flow_from_directory(val_path, batch_size = 32, target_size=(224,224), shuffle = True)
test_batches = ImageDataGenerator(rescale = 1./255).flow_from_directory(test_path, batch_size = 32, target_size=(224,224), shuffle = False)
# Out:
# Found 491 images belonging to 2 classes.
# Found 106 images belonging to 2 classes.
# Found 106 images belonging to 2 classes.

# %%
# Get the DenseNet base model
base_model = DenseNet169(include_top=False, pooling='avg')

# Make the base model untrainable
base_model.trainable = False

# Define the model
model = Sequential([
    base_model,
    Dense(2, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet169_weights_tf_dim_ordering_tf_kernels_notop.h5
# 51877672/51877672 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
callbacks = [EarlyStopping(patience=5, restore_best_weights=True),
             ModelCheckpoint(filepath='model.keras', save_best_only=True)]

# %%
history = model.fit(
    train_batches,
    steps_per_epoch = 100,
    validation_data = val_batches, 
    validation_steps = 100,
    epochs = 30)
# Out:
# Epoch 1/30
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
#  16/100 ━━━━━━━━━━━━━━━━━━━━ 4:57 4s/step - accuracy: 0.4273 - loss: 0.8783
# /opt/conda/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 125s 805ms/step - accuracy: 0.5115 - loss: 0.7801 - val_accuracy: 0.7736 - val_loss: 0.5677
# Epoch 2/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 87s 693ms/step - accuracy: 0.7556 - loss: 0.5340 - val_accuracy: 0.7925 - val_loss: 0.4832
# Epoch 3/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 89s 708ms/step - accuracy: 0.8188 - loss: 0.4442 - val_accuracy: 0.8491 - val_loss: 0.3990
# Epoch 4/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 89s 697ms/step - accuracy: 0.8441 - loss: 0.3754 - val_accuracy: 0.8491 - val_loss: 0.3752
# Epoch 5/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 89s 708ms/step - accuracy: 0.9043 - loss: 0.3172 - val_accuracy: 0.8396 - val_loss: 0.3406
# Epoch 6/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 141s 739ms/step - accuracy: 0.9179 - loss: 0.2799 - val_accuracy: 0.8868 - val_loss: 0.3001
# Epoch 7/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 142s 740ms/step - accuracy: 0.9195 - loss: 0.2549 - val_accuracy: 0.8585 - val_loss: 0.2891
# Epoch 8/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 94s 751ms/step - accuracy: 0.9266 - loss: 0.2301 - val_accuracy: 0.8962 - val_loss: 0.2522
# Epoch 9/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 137s 746ms/step - accuracy: 0.9446 - loss: 0.2096 - val_accuracy: 0.8962 - val_loss: 0.2348
# Epoch 10/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 142s 704ms/step - accuracy: 0.9476 - loss: 0.1962 - val_accuracy: 0.9340 - val_loss: 0.2366
# Epoch 11/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 89s 705ms/step - accuracy: 0.9308 - loss: 0.2089 - val_accuracy: 0.9340 - val_loss: 0.2045
# Epoch 12/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 143s 714ms/step - accuracy: 0.9533 - loss: 0.1766 - val_accuracy: 0.9151 - val_loss: 0.2034
# Epoch 13/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 144s 783ms/step - accuracy: 0.9623 - loss: 0.1631 - val_accuracy: 0.9151 - val_loss: 0.2046
# Epoch 14/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 137s 697ms/step - accuracy: 0.9651 - loss: 0.1506 - val_accuracy: 0.9340 - val_loss: 0.1814
# Epoch 15/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 143s 698ms/step - accuracy: 0.9701 - loss: 0.1471 - val_accuracy: 0.9340 - val_loss: 0.1694
# Epoch 16/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 94s 748ms/step - accuracy: 0.9591 - loss: 0.1406 - val_accuracy: 0.9340 - val_loss: 0.1611
# Epoch 17/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 136s 702ms/step - accuracy: 0.9726 - loss: 0.1338 - val_accuracy: 0.9340 - val_loss: 0.1575
# Epoch 18/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 142s 715ms/step - accuracy: 0.9787 - loss: 0.1235 - val_accuracy: 0.9245 - val_loss: 0.1702
# Epoch 19/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 143s 753ms/step - accuracy: 0.9740 - loss: 0.1190 - val_accuracy: 0.9528 - val_loss: 0.1507
# Epoch 20/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 89s 708ms/step - accuracy: 0.9838 - loss: 0.1135 - val_accuracy: 0.9528 - val_loss: 0.1414
# Epoch 21/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 143s 712ms/step - accuracy: 0.9858 - loss: 0.1088 - val_accuracy: 0.9528 - val_loss: 0.1373
# Epoch 22/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 94s 753ms/step - accuracy: 0.9878 - loss: 0.1036 - val_accuracy: 0.9434 - val_loss: 0.1561
# Epoch 23/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 138s 706ms/step - accuracy: 0.9850 - loss: 0.1034 - val_accuracy: 0.9528 - val_loss: 0.1317
# Epoch 24/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 140s 692ms/step - accuracy: 0.9873 - loss: 0.0983 - val_accuracy: 0.9434 - val_loss: 0.1342
# Epoch 25/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 93s 752ms/step - accuracy: 0.9895 - loss: 0.0931 - val_accuracy: 0.9528 - val_loss: 0.1250
# Epoch 26/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 136s 687ms/step - accuracy: 0.9880 - loss: 0.0900 - val_accuracy: 0.9528 - val_loss: 0.1130
# Epoch 27/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 145s 701ms/step - accuracy: 0.9909 - loss: 0.0883 - val_accuracy: 0.9528 - val_loss: 0.1108
# Epoch 28/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 146s 745ms/step - accuracy: 0.9961 - loss: 0.0855 - val_accuracy: 0.9528 - val_loss: 0.1169
# Epoch 29/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 88s 690ms/step - accuracy: 0.9953 - loss: 0.0807 - val_accuracy: 0.9528 - val_loss: 0.1117
# Epoch 30/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 86s 680ms/step - accuracy: 0.9963 - loss: 0.0762 - val_accuracy: 0.9528 - val_loss: 0.1141

# %%
loss, accuracy = model.evaluate(val_batches)
print(f'Loss: {loss}')
print(f'Accuracy: {accuracy}')
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 15s 3s/step - accuracy: 0.9582 - loss: 0.1099
# Loss: 0.11408588290214539
# Accuracy: 0.9528301954269409

# %%
# Plot training & validation accuracy values
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.tight_layout()
plt.show()

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ densenet169 (Functional)        │ (None, 1664)           │    12,642,880 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 2)              │         3,330 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 12,652,872 (48.27 MB)
#  Trainable params: 3,330 (13.01 KB)
#  Non-trainable params: 12,642,880 (48.23 MB)
#  Optimizer params: 6,662 (26.03 KB)

# %%
# fname = "weights-DenseNet169-DR.weights.h5"
# model.save_weights(fname, overwrite = True)

# %%
test_generator = ImageDataGenerator()
test_data_generator = test_generator.flow_from_directory(
    r'/kaggle/working/test', # Put your path here
     target_size=(224, 224),
    batch_size=32,
    shuffle=False)
test_steps_per_epoch = np.math.ceil(test_data_generator.samples / test_data_generator.batch_size)

# predictions = model.predict_generator(test_data_generator, steps=test_steps_per_epoch)
predictions = (model.predict(test_data_generator) > 0.5).astype("int32")
# Get most likely class
predicted_classes = np.argmax(predictions, axis=1)
# Out:
# Found 106 images belonging to 2 classes.
# /tmp/ipykernel_33/1476124348.py:7: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   test_steps_per_epoch = np.math.ceil(test_data_generator.samples / test_data_generator.batch_size)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 27s 5s/step

# %%
true_classes = test_data_generator.classes
class_labels = list(test_data_generator.class_indices.keys())

# %%
import sklearn.metrics as metrics

# %%
report = metrics.classification_report(true_classes, predicted_classes, target_names=class_labels)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#           DR       0.00      0.00      0.00        53
#        No_DR       0.50      1.00      0.67        53
#
#     accuracy                           0.50       106
#    macro avg       0.25      0.50      0.33       106
# weighted avg       0.25      0.50      0.33       106
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
