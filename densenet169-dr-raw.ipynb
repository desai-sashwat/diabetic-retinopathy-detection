# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/raw-dataset/raw_id.csv
# /kaggle/input/raw-dataset/Raw/DR/DR (29).jpg
# /kaggle/input/raw-dataset/Raw/DR/DR (41).jpg
# /kaggle/input/raw-dataset/Raw/DR/DR (18).jpg
# /kaggle/input/raw-dataset/Raw/DR/DR (17).jpg
# /kaggle/input/raw-dataset/Raw/DR/DR (7).jpg
# /kaggle/input/raw-dataset/Raw/DR/DR (13).jpg
# /kaggle/input/raw-dataset/Raw/DR/DR (39).jpg
# /kaggle/input/raw-dataset/Raw/DR/DR (27).jpg
# /kaggle/input/raw-dataset/Raw/DR/DR (43).jpg
# /kaggle/input/raw-dataset/Raw/DR/DR (9).jpg
# /kaggle/input/raw-dataset/Raw/DR/DR (35).jpg
# /kaggle/input/raw-dataset/Raw/DR/DR (22).jpg
# /kaggle/input/raw-dataset/Raw/DR/DR (2).jpg
# /kaggle/input/raw-dataset/Raw/DR/DR (42).jpg
# /kaggle/input/raw-dataset/Raw/DR/DR (49).jpg
# /kaggle/input/raw-dataset/Raw/DR/DR (33).jpg
# /kaggle/input/raw-dataset/Raw/DR/DR (21).jpg
# /kaggle/input/raw-dataset/Raw/DR/DR (37).jpg
# /kaggle/input/raw-dataset/Raw/DR/DR (5).jpg
# /kaggle/input/raw-dataset/Raw/DR/DR (50).jpg
# /kaggle/input/raw-dataset/Raw/DR/DR (45).jpg
# /kaggle/input/raw-dataset/Raw/DR/DR (40).jpg
# /kaggle/input/raw-dataset/Raw/DR/DR (23).jpg
# /kaggle/input/raw-dataset/Raw/DR/DR (6).jpg
# /kaggle/input/raw-dataset/Raw/DR/DR (10).jpg
# /kaggle/input/raw-dataset/Raw/DR/DR (38).jpg
# /kaggle/input/raw-dataset/Raw/DR/DR (48).jpg
# /kaggle/input/raw-dataset/Raw/DR/DR (47).jpg
# /kaggle/input/raw-dataset/Raw/DR/DR (51).jpg
# /kaggle/input/raw-dataset/Raw/DR/DR (44).jpg
# /kaggle/input/raw-dataset/Raw/DR/DR (31).jpg
# /kaggle/input/raw-dataset/Raw/DR/DR (36).jpg
# /kaggle/input/raw-dataset/Raw/DR/DR (52).jpg
# /kaggle/input/raw-dataset/Raw/DR/DR (34).jpg
# /kaggle/input/raw-dataset/Raw/DR/DR (20).jpg
# /kaggle/input/raw-dataset/Raw/DR/DR (3).jpg
# /kaggle/input/raw-dataset/Raw/DR/DR (15).jpg
# /kaggle/input/raw-dataset/Raw/DR/DR (26).jpg
# /kaggle/input/raw-dataset/Raw/DR/DR (46).jpg
# /kaggle/input/raw-dataset/Raw/DR/DR (30).jpg
# /kaggle/input/raw-dataset/Raw/DR/DR (24).jpg
# /kaggle/input/raw-dataset/Raw/DR/DR (16).jpg
# /kaggle/input/raw-dataset/Raw/DR/DR (8).jpg
# /kaggle/input/raw-dataset/Raw/DR/DR (1).jpg
# /kaggle/input/raw-dataset/Raw/DR/DR (11).jpg
# /kaggle/input/raw-dataset/Raw/DR/DR (12).jpg
# /kaggle/input/raw-dataset/Raw/DR/DR (32).jpg
# /kaggle/input/raw-dataset/Raw/DR/DR (19).jpg
# /kaggle/input/raw-dataset/Raw/DR/DR (4).jpg
# /kaggle/input/raw-dataset/Raw/DR/DR (14).jpg
# /kaggle/input/raw-dataset/Raw/DR/DR (28).jpg
# /kaggle/input/raw-dataset/Raw/DR/DR (25).jpg
# /kaggle/input/raw-dataset/Raw/NO DR/NDR (4).jpg
# /kaggle/input/raw-dataset/Raw/NO DR/NDR (7).jpg
# /kaggle/input/raw-dataset/Raw/NO DR/NDR (42).jpg
# /kaggle/input/raw-dataset/Raw/NO DR/NDR (45).jpg
# /kaggle/input/raw-dataset/Raw/NO DR/NDR (48).jpg
# /kaggle/input/raw-dataset/Raw/NO DR/NDR (24).jpg
# /kaggle/input/raw-dataset/Raw/NO DR/NDR (16).jpg
# /kaggle/input/raw-dataset/Raw/NO DR/NDR (9).jpg
# /kaggle/input/raw-dataset/Raw/NO DR/NDR (49).jpg
# /kaggle/input/raw-dataset/Raw/NO DR/NDR (14).jpg
# /kaggle/input/raw-dataset/Raw/NO DR/NDR (13).jpg
# /kaggle/input/raw-dataset/Raw/NO DR/NDR (21).jpg
# /kaggle/input/raw-dataset/Raw/NO DR/NDR (37).jpg
# /kaggle/input/raw-dataset/Raw/NO DR/NDR (22).jpg
# /kaggle/input/raw-dataset/Raw/NO DR/NDR (25).jpg
# /kaggle/input/raw-dataset/Raw/NO DR/NDR (33).jpg
# /kaggle/input/raw-dataset/Raw/NO DR/NDR (2).jpg
# /kaggle/input/raw-dataset/Raw/NO DR/NDR (40).jpg
# /kaggle/input/raw-dataset/Raw/NO DR/NDR (12).jpg
# /kaggle/input/raw-dataset/Raw/NO DR/NDR (17).jpg
# /kaggle/input/raw-dataset/Raw/NO DR/NDR (36).jpg
# /kaggle/input/raw-dataset/Raw/NO DR/NDR (1).jpg
# /kaggle/input/raw-dataset/Raw/NO DR/NDR (32).jpg
# /kaggle/input/raw-dataset/Raw/NO DR/NDR (39).jpg
# /kaggle/input/raw-dataset/Raw/NO DR/NDR (15).jpg
# /kaggle/input/raw-dataset/Raw/NO DR/NDR (10).jpg
# /kaggle/input/raw-dataset/Raw/NO DR/NDR (26).jpg
# /kaggle/input/raw-dataset/Raw/NO DR/NDR (35).jpg
# /kaggle/input/raw-dataset/Raw/NO DR/NDR (19).jpg
# /kaggle/input/raw-dataset/Raw/NO DR/NDR (11).jpg
# /kaggle/input/raw-dataset/Raw/NO DR/NDR (3).jpg
# /kaggle/input/raw-dataset/Raw/NO DR/NDR (5).jpg
# /kaggle/input/raw-dataset/Raw/NO DR/NDR (6).jpg
# /kaggle/input/raw-dataset/Raw/NO DR/NDR (20).jpg
# /kaggle/input/raw-dataset/Raw/NO DR/NDR (23).jpg
# /kaggle/input/raw-dataset/Raw/NO DR/NDR (29).jpg
# /kaggle/input/raw-dataset/Raw/NO DR/NDR (34).jpg
# /kaggle/input/raw-dataset/Raw/NO DR/NDR (31).jpg
# /kaggle/input/raw-dataset/Raw/NO DR/NDR (8).jpg
# /kaggle/input/raw-dataset/Raw/NO DR/NDR (50).jpg
# /kaggle/input/raw-dataset/Raw/NO DR/NDR (46).jpg
# /kaggle/input/raw-dataset/Raw/NO DR/NDR (27).jpg
# /kaggle/input/raw-dataset/Raw/NO DR/NDR (44).jpg
# /kaggle/input/raw-dataset/Raw/NO DR/NDR (28).jpg
# /kaggle/input/raw-dataset/Raw/NO DR/NDR (18).jpg
# /kaggle/input/raw-dataset/Raw/NO DR/NDR (47).jpg
# /kaggle/input/raw-dataset/Raw/NO DR/NDR (30).jpg
# /kaggle/input/raw-dataset/Raw/NO DR/NDR (41).jpg
# /kaggle/input/raw-dataset/Raw/NO DR/NDR (38).jpg
# /kaggle/input/raw-dataset/Raw/NO DR/NDR (43).jpg

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.applications import ResNet50
from keras.models import Sequential
from keras.layers import Dense, Flatten, GlobalAveragePooling2D
from keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.model_selection import train_test_split
import shutil
# Out:
# 2024-04-27 16:46:26.531217: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-27 16:46:26.531391: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-27 16:46:26.713772: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
from tensorflow.keras.applications.densenet import DenseNet121,DenseNet169

# %%
df = pd.read_csv(r'/kaggle/input/raw-dataset/raw_id.csv')

diagnosis_dict_binary = {
    0: 'NO DR',
    1: 'DR'
}

diagnosis_dict = {
    0: 'NO DR',
    1: 'DR'
}


df['binary_type'] =  df['diagnosis'].map(diagnosis_dict_binary.get)
df['type'] = df['diagnosis'].map(diagnosis_dict.get)

# %%
# Split into stratified train, val, and test sets
train_intermediate, val = train_test_split(df, test_size = 0.15, stratify = df['type'])
train, test = train_test_split(train_intermediate, test_size = 0.15 / (1 - 0.15), stratify = train_intermediate['type'])

print(train['type'].value_counts(), '\n')
print(test['type'].value_counts(), '\n')
print(val['type'].value_counts(), '\n')
# Out:
# type
# DR       36
# NO DR    34
# Name: count, dtype: int64
#
# type
# DR       8
# NO DR    8
# Name: count, dtype: int64
#
# type
# DR       8
# NO DR    8
# Name: count, dtype: int64

# %%
# Create working directories for train/val/test
base_dir = ''

train_dir = os.path.join(base_dir, 'train')
val_dir = os.path.join(base_dir, 'val')
test_dir = os.path.join(base_dir, 'test')

if os.path.exists(base_dir):
    shutil.rmtree(base_dir)

if os.path.exists(train_dir):
    shutil.rmtree(train_dir)
os.makedirs(train_dir)

if os.path.exists(val_dir):
    shutil.rmtree(val_dir)
os.makedirs(val_dir)

if os.path.exists(test_dir):
    shutil.rmtree(test_dir)
os.makedirs(test_dir)

# %%
# Copy images to respective working directory
src_dir = r'/kaggle/input/raw-dataset/Raw'
for index, row in train.iterrows():
    diagnosis = row['type']
    binary_diagnosis = row['binary_type']
    id_code = row['id_code'] + ".jpg"
    srcfile = os.path.join(src_dir, diagnosis, id_code)
    dstfile = os.path.join(train_dir, binary_diagnosis)
    os.makedirs(dstfile, exist_ok = True)
    shutil.copy(srcfile, dstfile)

for index, row in val.iterrows():
    diagnosis = row['type']
    binary_diagnosis = row['binary_type']
    id_code = row['id_code'] + ".jpg"
    srcfile = os.path.join(src_dir, diagnosis, id_code)
    dstfile = os.path.join(val_dir, binary_diagnosis)
    os.makedirs(dstfile, exist_ok = True)
    shutil.copy(srcfile, dstfile)
 
for index, row in test.iterrows():
    diagnosis = row['type']
    binary_diagnosis = row['binary_type']
    id_code = row['id_code'] + ".jpg"
    srcfile = os.path.join(src_dir, diagnosis, id_code)
    dstfile = os.path.join(test_dir, binary_diagnosis)
    os.makedirs(dstfile, exist_ok = True)
    shutil.copy(srcfile, dstfile)

# %%
# Setting up ImageDataGenerator for train/val/test 

train_path = 'train'
val_path = 'val'
test_path = 'test'

train_batches = ImageDataGenerator(rescale = 1./255).flow_from_directory(train_path, batch_size = 32, target_size=(224,224), shuffle = True)
val_batches = ImageDataGenerator(rescale = 1./255).flow_from_directory(val_path, batch_size = 32, target_size=(224,224), shuffle = True)
test_batches = ImageDataGenerator(rescale = 1./255).flow_from_directory(test_path, batch_size = 32, target_size=(224,224), shuffle = False)
# Out:
# Found 70 images belonging to 2 classes.
# Found 16 images belonging to 2 classes.
# Found 16 images belonging to 2 classes.

# %%
# Get the DenseNet base model
base_model = DenseNet169(include_top=False, pooling='avg')

# Make the base model untrainable
base_model.trainable = False

# Define the model
model = Sequential([
    base_model,
    Dense(2, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet169_weights_tf_dim_ordering_tf_kernels_notop.h5
# 51877672/51877672 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
callbacks = [EarlyStopping(patience=5, restore_best_weights=True),
             ModelCheckpoint(filepath='model.keras', save_best_only=True)]

# %%
history = model.fit(
    train_batches,
    steps_per_epoch = 100,
    validation_data = val_batches, 
    validation_steps = 100,
    epochs = 30)
# Out:
# Epoch 1/30
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
#   3/100 ━━━━━━━━━━━━━━━━━━━━ 3:01 2s/step - accuracy: 0.4442 - loss: 1.0340
# /opt/conda/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 46s 149ms/step - accuracy: 0.4429 - loss: 1.0118 - val_accuracy: 0.5625 - val_loss: 0.8913
# Epoch 2/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 16s 69ms/step - accuracy: 0.5417 - loss: 0.9104 - val_accuracy: 0.5000 - val_loss: 0.7152
# Epoch 3/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 17s 69ms/step - accuracy: 0.5436 - loss: 0.7173 - val_accuracy: 0.5625 - val_loss: 0.6270
# Epoch 4/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 16s 93ms/step - accuracy: 0.6995 - loss: 0.6003 - val_accuracy: 0.8125 - val_loss: 0.5307
# Epoch 5/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 16s 69ms/step - accuracy: 0.7864 - loss: 0.5503 - val_accuracy: 0.8125 - val_loss: 0.4543
# Epoch 6/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 16s 95ms/step - accuracy: 0.7703 - loss: 0.5080 - val_accuracy: 0.7500 - val_loss: 0.4335
# Epoch 7/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 16s 70ms/step - accuracy: 0.7853 - loss: 0.4904 - val_accuracy: 0.8125 - val_loss: 0.3900
# Epoch 8/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 16s 66ms/step - accuracy: 0.8435 - loss: 0.4450 - val_accuracy: 0.8125 - val_loss: 0.3690
# Epoch 9/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 16s 69ms/step - accuracy: 0.8443 - loss: 0.4174 - val_accuracy: 0.8125 - val_loss: 0.3484
# Epoch 10/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 16s 90ms/step - accuracy: 0.8148 - loss: 0.3871 - val_accuracy: 0.8750 - val_loss: 0.3354
# Epoch 11/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 16s 71ms/step - accuracy: 0.7866 - loss: 0.3803 - val_accuracy: 0.9375 - val_loss: 0.3329
# Epoch 12/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 16s 93ms/step - accuracy: 0.8428 - loss: 0.3549 - val_accuracy: 0.8750 - val_loss: 0.3327
# Epoch 13/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 17s 98ms/step - accuracy: 0.8584 - loss: 0.3290 - val_accuracy: 0.8750 - val_loss: 0.3346
# Epoch 14/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 16s 66ms/step - accuracy: 0.8858 - loss: 0.3189 - val_accuracy: 0.8750 - val_loss: 0.3388
# Epoch 15/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 16s 71ms/step - accuracy: 0.9146 - loss: 0.3056 - val_accuracy: 0.9375 - val_loss: 0.3395
# Epoch 16/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 16s 66ms/step - accuracy: 0.9151 - loss: 0.2943 - val_accuracy: 0.8750 - val_loss: 0.3336
# Epoch 17/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 16s 72ms/step - accuracy: 0.9426 - loss: 0.2860 - val_accuracy: 0.8750 - val_loss: 0.3351
# Epoch 18/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 16s 67ms/step - accuracy: 0.9572 - loss: 0.2636 - val_accuracy: 0.8750 - val_loss: 0.3423
# Epoch 19/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 16s 70ms/step - accuracy: 0.9574 - loss: 0.2735 - val_accuracy: 0.8750 - val_loss: 0.3876
# Epoch 20/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 16s 69ms/step - accuracy: 0.8864 - loss: 0.2769 - val_accuracy: 0.8750 - val_loss: 0.3615
# Epoch 21/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 16s 99ms/step - accuracy: 0.9572 - loss: 0.2442 - val_accuracy: 0.9375 - val_loss: 0.3347
# Epoch 22/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 16s 94ms/step - accuracy: 0.9717 - loss: 0.2399 - val_accuracy: 0.9375 - val_loss: 0.3525
# Epoch 23/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 16s 73ms/step - accuracy: 0.9712 - loss: 0.2376 - val_accuracy: 1.0000 - val_loss: 0.3393
# Epoch 24/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 16s 91ms/step - accuracy: 0.9857 - loss: 0.2181 - val_accuracy: 0.9375 - val_loss: 0.3256
# Epoch 25/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 17s 74ms/step - accuracy: 0.9855 - loss: 0.2042 - val_accuracy: 0.8750 - val_loss: 0.3241
# Epoch 26/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 16s 94ms/step - accuracy: 0.9720 - loss: 0.2108 - val_accuracy: 0.8750 - val_loss: 0.3419
# Epoch 27/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 16s 73ms/step - accuracy: 0.9714 - loss: 0.2048 - val_accuracy: 0.8750 - val_loss: 0.3099
# Epoch 28/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 16s 67ms/step - accuracy: 0.9858 - loss: 0.1852 - val_accuracy: 0.9375 - val_loss: 0.2968
# Epoch 29/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 16s 97ms/step - accuracy: 0.9857 - loss: 0.1892 - val_accuracy: 1.0000 - val_loss: 0.2977
# Epoch 30/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 16s 66ms/step - accuracy: 0.9860 - loss: 0.1902 - val_accuracy: 0.8750 - val_loss: 0.2908

# %%
loss, accuracy = model.evaluate(val_batches)
print(f'Loss: {loss}')
print(f'Accuracy: {accuracy}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - accuracy: 0.8750 - loss: 0.2908
# Loss: 0.29081153869628906
# Accuracy: 0.875

# %%
# Plot training & validation accuracy values
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.tight_layout()
plt.show()

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ densenet169 (Functional)        │ (None, 1664)           │    12,642,880 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 2)              │         3,330 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 12,652,872 (48.27 MB)
#  Trainable params: 3,330 (13.01 KB)
#  Non-trainable params: 12,642,880 (48.23 MB)
#  Optimizer params: 6,662 (26.03 KB)

# %%
# fname = "weights-DenseNet169-DR-Raw.weights.h5"
# model.save_weights(fname, overwrite = True)

# %%
test_generator = ImageDataGenerator()
test_data_generator = test_generator.flow_from_directory(
    r'/kaggle/working/test', # Put your path here
     target_size=(224, 224),
    batch_size=32,
    shuffle=False)
test_steps_per_epoch = np.math.ceil(test_data_generator.samples / test_data_generator.batch_size)

# predictions = model.predict_generator(test_data_generator, steps=test_steps_per_epoch)
predictions = (model.predict(test_data_generator) > 0.5).astype("int32")
# Get most likely class
predicted_classes = np.argmax(predictions, axis=1)
# Out:
# Found 16 images belonging to 2 classes.
# /tmp/ipykernel_33/1476124348.py:7: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   test_steps_per_epoch = np.math.ceil(test_data_generator.samples / test_data_generator.batch_size)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step

# %%
true_classes = test_data_generator.classes
class_labels = list(test_data_generator.class_indices.keys())

# %%
import sklearn.metrics as metrics

# %%
report = metrics.classification_report(true_classes, predicted_classes, target_names=class_labels, zero_division = 1)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#           DR       1.00      0.00      0.00         8
#        NO DR       0.50      1.00      0.67         8
#
#     accuracy                           0.50        16
#    macro avg       0.75      0.50      0.33        16
# weighted avg       0.75      0.50      0.33        16

# %%
model.save('/kaggle/working/model169.h5')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 model.save('/kaggle/working/model169.h5')
#
# File /opt/conda/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File /opt/conda/lib/python3.10/site-packages/h5py/_hl/group.py:183, in Group.create_dataset(self, name, shape, dtype, data, **kwds)
#     180         parent_path, name = name.rsplit(b'/', 1)
#     181         group = self.require_group(parent_path)
# --> 183 dsid = dataset.make_new_dset(group, shape, dtype, data, name, **kwds)
#     184 dset = dataset.Dataset(dsid)
#     185 return dset
#
# File /opt/conda/lib/python3.10/site-packages/h5py/_hl/dataset.py:163, in make_new_dset(parent, shape, dtype, data, name, chunks, compression, shuffle, fletcher32, maxshape, compression_opts, fillvalue, scaleoffset, track_times, external, track_order, dcpl, dapl, efile_prefix, virtual_prefix, allow_unknown_filter, rdcc_nslots, rdcc_nbytes, rdcc_w0)
#     160 else:
#     161     sid = h5s.create_simple(shape, maxshape)
# --> 163 dset_id = h5d.create(parent.id, name, tid, sid, dcpl=dcpl, dapl=dapl)
#     165 if (data is not None) and (not isinstance(data, Empty)):
#     166     dset_id.write(h5s.ALL, h5s.ALL, data)
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5d.pyx:137, in h5py.h5d.create()
#
# ValueError: Unable to synchronously create dataset (name already exists)
